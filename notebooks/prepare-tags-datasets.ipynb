# %%
import ast
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import Counter, defaultdict
from datasets import load_dataset

seed = 42
np.random.seed(seed)

# %% [markdown]
# ## Define Tag Categories

# %%
KNOWN_TAGS = json.load(open("../data/concepts_to_tags.json", "r"))

# Reverse map for easy lookup (tag -> category)
TAG_TO_CATEGORY = {}
for cat, tags in KNOWN_TAGS.items():
    for tag in tags:
        TAG_TO_CATEGORY[tag] = cat

# %% [markdown]
# ## MTG Jaemdo

# %%
out_buffer = []

with open("../data/mtg_jamendo/autotagging_top50tags.tsv", "r") as f:
    for line in f.readlines():
        strings = line.strip().split('\t')
        track_id = strings[0]
        tags = strings[5:]  # Assuming tags start from the 6th column
        out_buffer.append({
            "id": track_id,
            "tags": tags
        })
with open("../data/mtg_jamendo/autotagging_top50tags_processed.csv", "w") as f:
    f.write("id,tags\n")
    for item in out_buffer:
        f.write(f"{item['id']},\"{';'.join(item['tags'])}\"\n")

# %%
mtg_df = pd.read_csv("../data/mtg_jamendo/autotagging_top50tags_processed.csv", converters={
    'tags': lambda x: x.split(';')
})
mtg_df
# Out:
#                   id                                         tags
# 0           TRACK_ID                                       [TAGS]
# 1      track_0000215                              [genre---metal]
# 2      track_0000216                              [genre---metal]
# 3      track_0000219                              [genre---metal]
# 4      track_0000223                              [genre---metal]
# ...              ...                                          ...
# 54376  track_1422056  [genre---soundtrack, instrument---computer]
# 54377  track_1422057  [genre---soundtrack, instrument---computer]
# 54378  track_1422058  [genre---soundtrack, instrument---computer]
# 54379  track_1422059  [genre---soundtrack, instrument---computer]
# 54380  track_1422060  [genre---soundtrack, instrument---computer]
#
# [54381 rows x 2 columns]

# %%
# Parse tags into categories
def parse_tags(tags):
    return pd.Series({
        'genre_tags': [t for t in tags if TAG_TO_CATEGORY[t] == 'genre'],
        'mood_tags': [t for t in tags if TAG_TO_CATEGORY[t] == 'mood'],
        'instrument_tags': [t for t in tags if TAG_TO_CATEGORY[t] == 'instrument']
    })

def clean_tags(tags):
    _tags = ast.literal_eval(str(tags))
    _tags = [t.split('---')[-1].strip() for t in _tags]
    return [t.lower() for t in _tags if t.lower() in TAG_TO_CATEGORY]

mtg_df[['genre_tags', 'mood_tags', 'instrument_tags']] = mtg_df['tags'].apply(clean_tags).apply(parse_tags)
mtg_df['aspect_list'] = mtg_df.apply(lambda row: list(set(
    row['genre_tags'] + row['mood_tags'] + row['instrument_tags']
)), axis=1)
mtg_df
# Out:
#                   id                                         tags genre_tags  \
# 0           TRACK_ID                                       [TAGS]         []
# 1      track_0000215                              [genre---metal]    [metal]
# 2      track_0000216                              [genre---metal]    [metal]
# 3      track_0000219                              [genre---metal]    [metal]
# 4      track_0000223                              [genre---metal]    [metal]
# ...              ...                                          ...        ...
# 54376  track_1422056  [genre---soundtrack, instrument---computer]         []
# 54377  track_1422057  [genre---soundtrack, instrument---computer]         []
# 54378  track_1422058  [genre---soundtrack, instrument---computer]         []
# 54379  track_1422059  [genre---soundtrack, instrument---computer]         []
# 54380  track_1422060  [genre---soundtrack, instrument---computer]         []
#
#       mood_tags instrument_tags aspect_list
# 0            []              []          []
# 1            []              []     [metal]
# 2            []              []     [metal]
# 3            []              []     [metal]
# 4            []              []     [metal]
# ...         ...             ...         ...
# 54376        []              []          []
# 54377        []              []          []
# 54378        []              []          []
# 54379        []              []          []
# 54380        []              []          []
#
# [54381 rows x 6 columns]

# %%
mtg_df = mtg_df.where((mtg_df['genre_tags'].map(len) > 0) & (mtg_df['instrument_tags'].map(len) > 0)).dropna()
mtg_df
# Out:
#                   id                                               tags  \
# 607    track_0007391  [genre---electronic, genre---pop, instrument--...
# 1015   track_0015161  [genre---instrumentalpop, genre---pop, genre--...
# 1020   track_0015166  [genre---dance, genre---electronic, genre---po...
# 1021   track_0015167  [genre---chillout, genre---easylistening, genr...
# 1023   track_0015169  [genre---electronic, genre---instrumentalpop, ...
# ...              ...                                                ...
# 54313  track_1420702  [genre---dance, genre---easylistening, genre--...
# 54314  track_1420704  [genre---dance, genre---easylistening, instrum...
# 54315  track_1420705  [genre---dance, genre---easylistening, instrum...
# 54316  track_1420706  [genre---dance, genre---easylistening, instrum...
# 54317  track_1420707  [genre---chillout, genre---dance, genre---hous...
#
#                              genre_tags      mood_tags  \
# 607                   [electronic, pop]    [emotional]
# 1015                        [pop, rock]    [emotional]
# 1020   [dance, electronic, pop, techno]    [emotional]
# 1021                  [electronic, pop]    [emotional]
# 1023                  [electronic, pop]    [emotional]
# ...                                 ...            ...
# 54313                           [dance]  [funk, happy]
# 54314                           [dance]        [happy]
# 54315                           [dance]        [happy]
# 54316                           [dance]        [happy]
# 54317                    [dance, house]        [happy]
#
#                        instrument_tags  \
# 607    [bass, drums, guitar, keyboard]
# 1015                     [bass, drums]
# 1020                            [bass]
# 1021                    [bass, violin]
# 1023                     [bass, drums]
# ...                                ...
# 54313          [bass, drums, keyboard]
# 54314          [bass, drums, keyboard]
# 54315          [bass, drums, keyboard]
# 54316          [bass, drums, keyboard]
# 54317          [bass, drums, keyboard]
#
#                                              aspect_list
# 607    [drums, bass, guitar, electronic, emotional, p...
# 1015                 [drums, bass, rock, emotional, pop]
# 1020   [bass, electronic, dance, techno, emotional, pop]
# 1021          [bass, electronic, emotional, pop, violin]
# 1023           [drums, bass, electronic, emotional, pop]
# ...                                                  ...
# 54313        [drums, bass, dance, funk, keyboard, happy]
# 54314              [drums, bass, dance, keyboard, happy]
# 54315              [drums, bass, dance, keyboard, happy]
# 54316              [drums, bass, dance, keyboard, happy]
# 54317       [drums, bass, dance, keyboard, happy, house]
#
# [2041 rows x 6 columns]

# %%
mtg_df.to_csv("../data/mtg_jamendo/autotagging_top50tags_processed_cleaned.csv", index=False)

# %%
from sklearn.model_selection import train_test_split

df_train, df_valid = train_test_split(mtg_df, test_size=0.1, random_state=42)
df_valid, df_test = train_test_split(df_valid, test_size=0.5, random_state=42)

# %%
from pathlib import Path

# Create output directory
output_dir = Path("../data/mtg_jaemdo_tags_dataset/")
output_dir.mkdir(parents=True, exist_ok=True)

df_train.to_csv(output_dir / "train.csv", index=False)
df_valid.to_csv(output_dir / "validation.csv", index=False)
df_test.to_csv(output_dir / "test.csv", index=False)
all_df = pd.concat([df_train, df_valid, df_test])
all_df.to_csv(output_dir / "all.csv", index=False)

# %%
data_files = {
    "train": str(output_dir / "train.csv"),
    "validation": str(output_dir / "validation.csv"),
    "test": str(output_dir / "test.csv")
}
dataset = load_dataset("csv", data_files=data_files)
dataset.push_to_hub("bsienkiewicz/mtg-jaemdo-tags-dataset", private=True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md:   0%|          | 0.00/814 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/bsienkiewicz/vae-tags-dataset/commit/c0136e1c1c9d98d142055fe328c7f214ded83b28', commit_message='Upload dataset', commit_description='', oid='c0136e1c1c9d98d142055fe328c7f214ded83b28', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/bsienkiewicz/vae-tags-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='bsienkiewicz/vae-tags-dataset'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## MSD

# %%
msd_df = load_dataset("seungheondoh/LP-MusicCaps-MSD")["train"].to_pandas()
msd_df
# Out:
#                   track_id                           title  \
# 0       TRSAGNY128F425391E      What Are You Fighting For?
# 1       TRPYJDT128F931E7BB                       Dope Nose
# 2       TRJIJTW128F4289A7E        500 Miles Away From Home
# 3       TRUZCQS12903CDCFD1          San Antonio Foam Party
# 4       TRDYVGM128F146186E                    They Rage On
# ...                    ...                             ...
# 444860  TRSRTSZ128F426826F  Let's Make A Night To Remember
# 444861  TRMTMCJ128F92F8A19            Civilization Machine
# 444862  TRJIIXA128F1490FD8                   How Do I Live
# 444863  TRQPESG128F9300304             Inter-Lergen-Ten-Ko
# 444864  TRUKJCU128F14653C5                    Ana Oualache
#
#                    artist_name                    release  year  \
# 0                Youth Brigade      Sink With Kalifornija  1984
# 1                       Weezer     The Lion And The Witch  2002
# 2                   Bobby Bare                 Super Hits  1988
# 3        Half Man Half Biscuit  Cammell Laird Social Club  2002
# 4                    DAN SEALS             Certified Hits  1988
# ...                        ...                        ...   ...
# 444860               Studio 99   A Tribute To Bryan Adams     0
# 444861       The Plastic Cloud          The Plastic Cloud  1968
# 444862              James Last              Country Roads  1998
# 444863  The Sabres Of Paradise                 Sabresonic  1993
# 444864               Cheb Mami                    Dellali  2001
#
#                                                       tag  \
# 0       [cathartic, earnest, punk, urgent, confident, ...
# 1       [hanging out, giddy, alternative pop rock, roc...
# 2       [laid back mellow, reflective, dramatic, organ...
# 3               [alternative indie rock, pop rock, indie]
# 4       [reflective, delicate, soft rock, day driving,...
# ...                                                   ...
# 444860                                         [pop rock]
# 444861  [psychedelic pop, folk rock, pop rock, psyched...
# 444862  [big band, laid back mellow, easy listening, j...
# 444863  [club dance, electronica, techno, electronic, ...
# 444864  [passionate, stylish, energetic, fun, african ...
#
#                                           caption_writing  \
# 0       This aggressive, confrontational, and energeti...
# 1       This alternative indie rock song combines gidd...
# 2       This song's Nashville Sound Countrypolitan ble...
# 3       Get lost in the captivating sound of alternati...
# 4       Take a nostalgic journey down memory lane with...
# ...                                                   ...
# 444860  Get ready to experience the perfect fusion of ...
# 444861  This mind-bending tune combines the raw energy...
# 444862  This easy listening instrumental pop track is ...
# 444863  This electronic techno track incorporates elem...
# 444864  This lively and stylish worldbeat song blends ...
#
#                                           caption_summary  \
# 0       This song is an explosive and cathartic anthem...
# 1       The song is a playful and fun alternative indi...
# 2       A melancholic, reflective, and bittersweet cou...
# 3       An upbeat and energetic indie-pop rock song wi...
# 4       A sentimental and reflective country pop song ...
# ...                                                   ...
# 444860  The song has a catchy beat and upbeat rock ins...
# 444861  A genre-bending song that blends psychedelic g...
# 444862  This instrumental pop-jazz song is a laid-back...
# 444863  This electronic song is a combination of techn...
# 444864  This song is a stylish and freewheeling celebr...
#
#                                        caption_paraphrase  \
# 0       This alternative indie rock anthem brings a ro...
# 1       Get ready to experience a roller-coaster of em...
# 2       This Nashville sound countrypolitan ballad is ...
# 3       This song is a captivating blend of alternativ...
# 4       This song is a sentimental journey through a S...
# ...                                                   ...
# 444860  This dynamic pop rock anthem is the perfect fu...
# 444861  Embodying the vintage sounds of psychedelic ga...
# 444862  This instrumental pop track boasts a laid back...
# 444863  Get lost in the hypnotic rhythms of this elect...
# 444864  This song is a stylish and freewheeling celebr...
#
#                              caption_attribute_prediction  \
# 0       This alternative indie rock anthem is aggressi...
# 1       This alternative indie rock song has a crunchy...
# 2       This country song has a weary, poignant feel t...
# 3       This indie rock/pop rock song is a unique, exp...
# 4       This pop rock song takes you on a Sunday after...
# ...                                                   ...
# 444860  This upbeat pop rock anthem will have you danc...
# 444861  This song is a trippy blend of psychedelic gar...
# 444862  This instrumental pop song has a laid back mel...
# 444863  This experimental electronic track combines el...
# 444864  This song is a vibrant fusion of international...
#
#                         path
# 0       2/7/2751652.clip.mp3
# 1       5/5/5529351.clip.mp3
# 2       3/3/3320516.clip.mp3
# 3       8/5/8539522.clip.mp3
# 4        2/7/279739.clip.mp3
# ...                      ...
# 444860  2/2/2251408.clip.mp3
# 444861  6/8/6814085.clip.mp3
# 444862   5/3/530277.clip.mp3
# 444863  5/8/5889307.clip.mp3
# 444864   2/9/297672.clip.mp3
#
# [444865 rows x 11 columns]

# %% [markdown]
# ## MTT

# %%
mtt_df = load_dataset("seungheondoh/LP-MusicCaps-MTT")["train"].to_pandas()
mtt_df
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-28dbf9154d6d52(…):   0%|          | 0.00/5.81M [00:00<?, ?B/s]
# data/test-00000-of-00001-94781ef88fa7ed8(…):   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# data/valid-00000-of-00001-bf9893b31ca2d5(…):   0%|          | 0.00/558k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/18706 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5329 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/1825 [00:00<?, ? examples/s]
#       track_id                                              title  \
# 0           25  Gleichwie der Regen und Schnee vom Himmel fall...
# 1           29  Gleichwie der Regen und Schnee vom Himmel fall...
# 2           39  Musicalische Exequien SWV 279 Teil I_ Concert ...
# 3           40  Musicalische Exequien SWV 279 Teil I_ Concert ...
# 4           44  Musicalische Exequien SWV 279 Teil I_ Concert ...
# ...        ...                                                ...
# 18701    58899                                      La Bressanina
# 18702    58906                                 Lost is my Lyberty
# 18703    58907                                 Lost is my Lyberty
# 18704    58908                                 Lost is my Lyberty
# 18705    58915                            A Toy for Monica Bishop
#
#                   artist_name                                  release  \
# 0      American Bach Soloists            J.S. Bach - Cantatas Volume V
# 1      American Bach Soloists            J.S. Bach - Cantatas Volume V
# 2      American Bach Soloists  Heinrich Schutz - Musicalische Exequien
# 3      American Bach Soloists  Heinrich Schutz - Musicalische Exequien
# 4      American Bach Soloists  Heinrich Schutz - Musicalische Exequien
# ...                       ...                                      ...
# 18701         Jacob Heringman                        Blame Not My Lute
# 18702         Jacob Heringman                        Blame Not My Lute
# 18703         Jacob Heringman                        Blame Not My Lute
# 18704         Jacob Heringman                        Blame Not My Lute
# 18705         Jacob Heringman                        Blame Not My Lute
#
#                                                tag_top50  \
# 0                                                     []
# 1                                    [classical, violin]
# 2                                                 [slow]
# 3                                          [opera, male]
# 4                                                [opera]
# ...                                                  ...
# 18701                                           [guitar]
# 18702          [guitar, solo, strings, harp, slow, soft]
# 18703                 [classical, guitar, strings, slow]
# 18704  [classical, guitar, quiet, solo, classic, slow...
# 18705                          [classical, guitar, slow]
#
#                                               tag_top188  \
# 0                                                     []
# 1                                    [classical, violin]
# 2                                                 [slow]
# 3                                          [opera, male]
# 4                                                [opera]
# ...                                                  ...
# 18701                         [guitar, classical guitar]
# 18702  [guitar, solo, strings, medieval, harp, slow, ...
# 18703                 [classical, guitar, strings, slow]
# 18704  [classical, guitar, quiet, solo, classic, mell...
# 18705                          [classical, guitar, slow]
#
#                                          caption_writing  \
# 0
# 1      Immerse yourself in the ethereal world of clas...
# 2      This heartfelt ballad takes the listener on a ...
# 3      Experience the grandeur and power of a timeles...
# 4      This song is a powerful and grandiose opera ma...
# ...                                                  ...
# 18701  A beautifully crafted song featuring the gentl...
# 18702  This hauntingly beautiful ballad features a sl...
# 18703  This beautiful classical piece features a gent...
# 18704  This classical guitar solo is a classic mellow...
# 18705  This beautiful classical guitar melody is slow...
#
#                                          caption_summary  \
# 0
# 1      A hauntingly beautiful composition showcasing ...
# 2      A melancholic ballad that mesmerizes with its ...
# 3      A powerful male opera performance that showcas...
# 4      A powerful operatic ballad that showcases the ...
# ...                                                  ...
# 18701  The song features delicate classical guitar me...
# 18702  A slow, soft medieval melody featuring a guita...
# 18703  A slow and melancholic piece featuring classic...
# 18704  A beautiful and melodic solo classical guitar ...
# 18705  A slow melancholic masterpiece played on class...
#
#                                       caption_paraphrase  \
# 0
# 1      Immerse yourself in the enchanting realm of cl...
# 2      This tender and leisurely track sets a tranqui...
# 3      In this captivating opera piece, a male vocali...
# 4      This song showcases the grandiose and dramatic...
# ...                                                  ...
# 18701  The melodic strums of a classical guitar weave...
# 18702  This ethereal piece features a gentle guitar s...
# 18703  This exquisite composition gracefully combines...
# 18704  Embrace the timeless beauty of this classic an...
# 18705  This classical guitar ballad sets a leisurely ...
#
#                             caption_attribute_prediction  \
# 0
# 1      This classical piece featuring the enchanting ...
# 2      A slow and relaxing song that helps you unwind...
# 3      This opera is a powerful and dramatic performa...
# 4      A soaring soprano voice takes center stage in ...
# ...                                                  ...
# 18701  This song is filled with the entrancing strums...
# 18702  This slow and soft medieval ballad features a ...
# 18703  This soul-stirring piece of music features slo...
# 18704  This beautiful classical guitar song is a quie...
# 18705  This song is a slow classical guitar piece fil...
#
#                                      pseudo_attribute  \
# 0                                                  []
# 1                    [orchestra, piano, cello, opera]
# 2                                          [relaxing]
# 3                    [dramatic, aria, tenor, soprano]
# 4                                           [soprano]
# ...                                               ...
# 18701              [acoustic guitar, electric guitar]
# 18702           [acoustic, melancholic, folk, ballad]
# 18703                    [melancholic, piano, violin]
# 18704  [melancholic, introspective, acoustic, serene]
# 18705               [romantic, acoustic, melancholic]
#
#                                                     path
# 0      0/american_bach_soloists-j_s__bach__cantatas_v...
# 1      0/american_bach_soloists-j_s__bach__cantatas_v...
# 2      9/american_bach_soloists-heinrich_schutz__musi...
# 3      9/american_bach_soloists-heinrich_schutz__musi...
# 4      9/american_bach_soloists-heinrich_schutz__musi...
# ...                                                  ...
# 18701  8/jacob_heringman-blame_not_my_lute-56-la_bres...
# 18702  8/jacob_heringman-blame_not_my_lute-57-lost_is...
# 18703  8/jacob_heringman-blame_not_my_lute-57-lost_is...
# 18704  8/jacob_heringman-blame_not_my_lute-57-lost_is...
# 18705  8/jacob_heringman-blame_not_my_lute-58-a_toy_f...
#
# [18706 rows x 12 columns]
